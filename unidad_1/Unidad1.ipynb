# %% [markdown]
# Ejemplo 1

# %%
import cv2 #opencv
import numpy as nu
import matplotlib.pyplot  as plt
#cargar una imagen
path ="../imagenes/pardoOriginal.png"
imagen=cv2.imread(path)

plt.imshow(cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB))
plt.title("Pardo")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
path ="../imagenes/pardoOriginal.png"
plt.rcParams['figure.figsize']=10,5
img=cv2.imread(path)
plt.imshow(img)
plt.show()
print("tamanio de la imgen",img.shape)
# Out:
# tamanio de la imgen (557, 448, 3)

# %%
import cv2 
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[10,5]
path="./imagenes/polarOriginal.jpg"
img=cv2.imread(path,cv2.IMREAD_COLOR)

plt.subplot(141)
plt.title("imgen Original")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

plt.subplot(142)
plt.imshow(img[:,:,0],cmap='gray')
plt.title("Canal Rojo")

plt.subplot(143)
plt.imshow(img[:,:,1],cmap='gray')
plt.title("Canal Verde")

plt.subplot(144)
plt.imshow(img[:,:,2],cmap='gray')
plt.title("Canal Azul")

plt.show()

# %% [markdown]
# Canales y colores reales

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize']=[10,5]
path="./imagenes/polarOriginal.jpg"
img=cv2.imread(path,cv2.IMREAD_COLOR)
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
r=img[:,:,2]
g=img[:,:,1]
b=img[:,:,0]

r_img=np.zeros_like(img_rgb)
r_img[:,:,0]=r

g_img=np.zeros_like(img_rgb)
g_img[:,:,1]=g

b_img=np.zeros_like(img_rgb)
b_img[:,:,2]=b

plt.subplot(1,4,1)
plt.title("Imagen Original")
plt.imshow(img_rgb)

plt.subplot(1,4,2)
plt.title("Canal Rojo")
plt.imshow(r_img)

plt.subplot(1,4,3)
plt.title("Canal verde")
plt.imshow(g_img)

plt.subplot(1,4,4)
plt.title("Canal Azul")
plt.imshow(b_img)

# %% [markdown]
# Colores falsos

# %%
import cv2 
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=[10,5]
path="../imagenes/polarOriginal.jpg"
img=cv2.imread(path,cv2.IMREAD_COLOR)
b,g,r=cv2.split(img)

plt.subplot(141)
plt.title('Original')
plt.imshow(cv2.cvtColor(img_rgb,cv2.COLOR_BGR2RGB))


plt.subplot(142)
plt.title('Canal Rojo')
plt.imshow(r,cmap="Reds")

plt.subplot(143)
plt.title('Canal Verde')
plt.imshow(r,cmap="Greens")

plt.subplot(144)
plt.title('Canal Azul')
plt.imshow(r,cmap="Blues")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 11
#       9 plt.subplot(141)
#      10 plt.title('Original')
# ---> 11 plt.imshow(cv2.cvtColor(img_rgb,cv2.COLOR_BGR2RGB))
#      14 plt.subplot(142)
#      15 plt.title('Canal Rojo')
#
# NameError: name 'img_rgb' is not defined

# %% [markdown]
# Otro uso de PLT

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

path="../imagenes/polarOriginal.jpg"
img_bgr =cv2.imread(path)
img_rgb=cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB)
print(f"Alto: {img_bgr.shape[0]}")
print(f"Ancho: {img_bgr.shape[1]}")
print(f"cananles: {img_bgr.shape[2]}")
fig,axs=plt.subplots(1,4,figsize=(20,5))

axs[0].imshow(img_rgb)
axs[0].set_title("Imagen original")

fig_img=axs[1].imshow(img_rgb[...,0],cmap='gray')
fig.colorbar(fig_img,ax=axs[1],shrink=0.5)
axs[1].set_title('canal Rojo')

img_g=axs[2].imshow(img_rgb[...,1],cmap='gray')
fig.colorbar(fig_img,ax=axs[2],shrink=0.5)
axs[2].set_title("Canal Verder")

img_b=axs[3].imshow(img_rgb[...,2],cmap='gray')
fig.colorbar(fig_img,ax=axs[3],shrink=0.5)
axs[3].set_title("Canal Azul")
# Out:
# Alto: 299
# Ancho: 168
# cananles: 3
# Text(0.5, 1.0, 'Canal Azul')

# %%
img_rgb[:3,:3,:]
# Out:
# array([[[206, 108, 147],
#         [206, 108, 147],
#         [206, 108, 147]],
#
#        [[206, 108, 147],
#         [206, 108, 147],
#         [206, 108, 147]],
#
#        [[206, 108, 147],
#         [206, 108, 147],
#         [206, 108, 147]]], dtype=uint8)

# %%
plt.imshow(img_rgb[:10,:10,:])

# %%
import cv2
cv2.imwrite('./img_modificadas/img1.png',img_bgr)
#cv2.imwrite('./tratadas/img2_r.png',fig_img)
#cv2.imwrite('./tratadas/img3_g.png',img_g)
#cv2.imwrite('./tratadas/img4_b.png',img_b)
#plt.imsave('img3.png',cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB))
# Out:
# True
